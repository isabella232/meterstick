# %% [markdown]
# go/meterstick-demo-pssession

# %% [markdown]
# #Summary
#
# Fully supported:
#
# *   Raw column name, like cpc_cost_usd.
# *   Raw table name, like shopping_analysis.ps_session.all.
# *   Complete query, like SELECT * FROM shopping_analysis.ps_session.all, UNNEST(ps_event).
#
# Partially supported:
#
# *   table.column, like ev.cpc_cost_usd.
#
# Preaggregating data can save memory.

# %%
from colabtools import adhoc_import

with adhoc_import.Google3():
  from meterstick.v2 import *

# %%
# %%dremel
# SET SQL_DIALECT GOOGLESQL;
# SET MIN_COMPLETION_RATIO 1;
# Out:
# Done! Processed commands DEFINE: 0, LOAD: 0, SET: 2

# %% [markdown]
# ## MH Metrics

# %%
table = '''shopping_analysis.ps_session.all AS t,
UNNEST(t.ps_event) AS ev,
UNNEST(ev.experimentid) AS expt_id,
UNNEST(ev.impression_set) AS imp'''

filters = '''
  _PARTITION_DATE BETWEEN '20200904' AND '20200905'
  AND ev.page_type != 'AFS'
  AND ev.good_for_revenue
  AND imp.slot > 0
  AND imp.impression_type = 'PLA'
  AND imp.clicks_valid_for_revenue > 0
  AND conversion_within_threshold
  AND expt_id IN (2004375, 2004376)'''

spend = 'cpc_cost_usd'
conversions = 'conversions_valid_for_revenue'
clicks = 'clicks_valid_for_revenue'
cvr = Ratio(conversions, clicks, 'cvr')
cpc = Ratio(spend, clicks, 'cpc')
cpd = Ratio(conversions, spend, 'cpd')
ms = MetricList((cpc, cvr, cpd), where=filters)
mh = MH('expt_id', 2004375, 'ads_customer_id', ms)
jk = Jackknife('rasta_cookie_bucket', mh, 0.95)
res = jk.compute_on_sql(table)
res
# Out:
# Metric  cpc_mh_ratio                     ...       cpd_mh_ratio
#                Value Jackknife CI-lower  ... Jackknife CI-lower Jackknife CI-upper
# expt_id                                  ...
# 2004376     0.063509          -0.282558  ...           -0.55014           1.133661
#
# [1 rows x 9 columns]

# %%
res.display(metric_formats={'Ratio': '{:.3f}%'})
# Out:
# <script src="https://ssl.gstatic.com/colaboratory/data_table/a6224c040fa35dcf/data_table.js" type="module"></script><div id="IT_id_771092927"></div><script>
#       (() => {
#         const data = [["<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.064%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.283%, 0.410%]<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.377%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.352%, 1.107%]<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.292%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.550%, 1.134%]<\/span><\/div><\/div>"]];
#         const kernelTag = "IT_id_771092927";
#         const listenerId = "Lstid_771092927";
#         const saveCallback = (indices) => {
#         const max = 5000;
#         colabtools.sendMessageToKernel(kernelTag, {action: 'clear'});
#         // Send data back to ipython in batches of 5k indices at a time.
#         // Otherwise notebook silently fails at ~10K indices.
#         for (let i = 0; i < (indices.length - 1) / max + 1; i++) {
#           const indiceList = indices.slice(i * max, (i + 1) * max);
#           colabtools.sendMessageToKernel(
#               kernelTag, {action: 'append', indices: indiceList});
#         }
#         colab.sendMessageToListeners(listenerId);
#       };
#         gvizInteractiveTable.create({
#           data,
#           saveCallback,
#           elementId: "IT_id_771092927",
#           columns: [["string", "cpc_mh_ratio"], ["string", "cvr_mh_ratio"], ["string", "cpd_mh_ratio"]],
#           columnOptions: null,
#           rowsPerPage: 100,
#           helpUrl: "https://colab.corp.google.com/notebooks/interactive_table.ipynb",
#           disableXssSanitization: false,
#           renderAsPlainText: false,
#           suppressOutputScrolling: true,
#         });
#       })();
#     //# sourceURL=table_IT_id_771092927
#     </script>
# <p id=feature-request-footnote><small id=feature-request-auto-hide>Click <a href="http://b/new?component=459832">here</a> to submit bugs or feature requests for the display function.</small></p>
# <style>
#   /* Use light mode CSS even in dark mode to make things consistent. Taken from
#     http://google3/research/colab/frontend/common/output/theme.css
#   */
#   body {
#     --colab-anchor-color: #00e;
#     --colab-primary-text-color: var(--paper-grey-900);
#     --colab-primary-surface-color: var(--paper-white);
#     --colab-secondary-surface-color: #f7f7f7;
#     --colab-highlighted-surface-color: var(--paper-grey-300);
#     --colab-border-color: #dadada;
#     --colab-bold-border-color: #111;
#     --colab-icon-color: #616161;
#   }
#
#   /* For the whole table body. */
#   tbody {
#     text-align: center;
#   }
#
#   /* Make the table scrollable */
#   .google-visualization-table > div:first-child {
#     max-height: 700px;
#   }
#
#   /* When scrolling, the first row of the table keeps its white background */
#   colab-interactive-table .google-visualization-table-tr-head
#     .google-visualization-table-th {
#     background: white;
#   }
#
#   .google-visualization-table {
#     width: auto !important;  /* To disable table from taking up full width. */
#   }
#
#   .google-visualization-table-table {
#     font-size: 10.5pt;  /* Font size for the whole table. */
#   }
#
#   /* Wrap the long column name. */
#   .google-visualization-table-th {
#     max-width: 120px;
#     white-space: normal !important;
#     word-wrap: break-word;
#   }
#
#   /* Get rid of the white padding around color cells. */
#   .google-visualization-table-td {
#     height: 1px;  /* Let the cell grow with text. */
#     padding: 0.5px !important;
#   }
#
#   .ci-display-cell{
#     height: 100%;
#     padding: 5px;
#     /* Center the content in the cell. */
#     display: flex;
#     align-items: center;
#     justify-content: center;
#   }
#
#   /* Formats Dimension column if there is one. */
#   .ci-display-dimension {
#     color: green;
#     padding: 2px;
#   }
#
#   /* Renders the description text. */
#   .ci-display-description-text {
#     color: black;
#   }
#
#   /* Renders the experiment id in blue. */
#   .ci-display-experiment-id {
#     color: #15c;
#   }
#
#   /* Break line in a flex display. */
#   .ci-display-flex-line-break {
#     width: 100%;
#   }
#
#   /* Renders the cells w/ positive confidence interval to green. */
#   .ci-display-good-change {
#     background-color: rgb(221,255,187);
#     color: green;
#   }
#
#   /* Renders the cells w/ negative confidence interval to red. */
#   .ci-display-bad-change {
#     background-color: rgb(255,221,187);
#     color: red;
#   }
#
#   .ci-display-ratio {
#     font-size: 120%; /* Renders the ratio value in larger font. */
#   }
#
#   .ci-display-ci-range {
#     white-space: nowrap;  /* Don't break line in the middle of CI range.
#   }
#
#   /* Display the footnote message for 5s then fade out. Adjusted from */
#   /* https://stackoverflow.com/a/43397509/2771265. */
#   #feature-request-footnote {
#     overflow:hidden;
#     position:relative;
#   }
#
#   #feature-request-auto-hide {
#     -webkit-animation: css-animation 10s forwards;
#     animation: css-animation 10s forwards;
#   }
#
#   @keyframes css-animation {
#     0%   {opacity: 1;}
#     100% {opacity: 0;}
#   }
#
#   @-webkit-keyframes css-animation {
#     0%   {opacity: 1;}
#     100% {opacity: 0;}
#   }
# </style>

# %% [markdown]
# Agrees to [SEAT](https://gearloose.corp.google.com/#/seat/FK0AQR/results).
#
# ![SEAT](https://screenshot.googleplex.com/7eixS6HXD9N4KVU.png)
#
# But SEAT doesn't support MH with slicing.

# %%
res = jk.compute_on_sql(table, 'ux_interface')
res
# Out:
# Metric               cpc_mh_ratio  ...       cpd_mh_ratio
#                             Value  ... Jackknife CI-upper
# ux_interface expt_id               ...
# 1            2004376    -0.053896  ...           2.032925
# 2            2004376     0.064048  ...           1.391591
# 3            2004376     0.776793  ...           6.674100
#
# [3 rows x 9 columns]

# %%
res.display()
# Out:
# <script src="https://ssl.gstatic.com/colaboratory/data_table/a6224c040fa35dcf/data_table.js" type="module"></script><div id="IT_id_771092996"></div><script>
#       (() => {
#         const data = [["<div><div><span class=\"ci-display-dimension\">1<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">-0.05%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.55, 0.44] %<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.15%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-1.48, 1.78] %<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.25%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-1.53, 2.03] %<\/span><\/div><\/div>"],
#  ["<div><div><span class=\"ci-display-dimension\">2<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.06%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.15, 0.28] %<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.50%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.32, 1.33] %<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.38%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.63, 1.39] %<\/span><\/div><\/div>"],
#  ["<div><div><span class=\"ci-display-dimension\">3<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.78%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.10, 1.65] %<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">1.26%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-5.34, 7.86] %<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">-0.18%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-7.03, 6.67] %<\/span><\/div><\/div>"]];
#         const kernelTag = "IT_id_771092996";
#         const listenerId = "Lstid_771092996";
#         const saveCallback = (indices) => {
#         const max = 5000;
#         colabtools.sendMessageToKernel(kernelTag, {action: 'clear'});
#         // Send data back to ipython in batches of 5k indices at a time.
#         // Otherwise notebook silently fails at ~10K indices.
#         for (let i = 0; i < (indices.length - 1) / max + 1; i++) {
#           const indiceList = indices.slice(i * max, (i + 1) * max);
#           colabtools.sendMessageToKernel(
#               kernelTag, {action: 'append', indices: indiceList});
#         }
#         colab.sendMessageToListeners(listenerId);
#       };
#         gvizInteractiveTable.create({
#           data,
#           saveCallback,
#           elementId: "IT_id_771092996",
#           columns: [["string", "Dimensions"], ["string", "cpc_mh_ratio"], ["string", "cvr_mh_ratio"], ["string", "cpd_mh_ratio"]],
#           columnOptions: null,
#           rowsPerPage: 100,
#           helpUrl: "https://colab.corp.google.com/notebooks/interactive_table.ipynb",
#           disableXssSanitization: false,
#           renderAsPlainText: false,
#           suppressOutputScrolling: true,
#         });
#       })();
#     //# sourceURL=table_IT_id_771092996
#     </script>
# <p id=feature-request-footnote><small id=feature-request-auto-hide>Click <a href="http://b/new?component=459832">here</a> to submit bugs or feature requests for the display function.</small></p>
# <style>
#   /* Use light mode CSS even in dark mode to make things consistent. Taken from
#     http://google3/research/colab/frontend/common/output/theme.css
#   */
#   body {
#     --colab-anchor-color: #00e;
#     --colab-primary-text-color: var(--paper-grey-900);
#     --colab-primary-surface-color: var(--paper-white);
#     --colab-secondary-surface-color: #f7f7f7;
#     --colab-highlighted-surface-color: var(--paper-grey-300);
#     --colab-border-color: #dadada;
#     --colab-bold-border-color: #111;
#     --colab-icon-color: #616161;
#   }
#
#   /* For the whole table body. */
#   tbody {
#     text-align: center;
#   }
#
#   /* Make the table scrollable */
#   .google-visualization-table > div:first-child {
#     max-height: 700px;
#   }
#
#   /* When scrolling, the first row of the table keeps its white background */
#   colab-interactive-table .google-visualization-table-tr-head
#     .google-visualization-table-th {
#     background: white;
#   }
#
#   .google-visualization-table {
#     width: auto !important;  /* To disable table from taking up full width. */
#   }
#
#   .google-visualization-table-table {
#     font-size: 10.5pt;  /* Font size for the whole table. */
#   }
#
#   /* Wrap the long column name. */
#   .google-visualization-table-th {
#     max-width: 120px;
#     white-space: normal !important;
#     word-wrap: break-word;
#   }
#
#   /* Get rid of the white padding around color cells. */
#   .google-visualization-table-td {
#     height: 1px;  /* Let the cell grow with text. */
#     padding: 0.5px !important;
#   }
#
#   .ci-display-cell{
#     height: 100%;
#     padding: 5px;
#     /* Center the content in the cell. */
#     display: flex;
#     align-items: center;
#     justify-content: center;
#   }
#
#   /* Formats Dimension column if there is one. */
#   .ci-display-dimension {
#     color: green;
#     padding: 2px;
#   }
#
#   /* Renders the description text. */
#   .ci-display-description-text {
#     color: black;
#   }
#
#   /* Renders the experiment id in blue. */
#   .ci-display-experiment-id {
#     color: #15c;
#   }
#
#   /* Break line in a flex display. */
#   .ci-display-flex-line-break {
#     width: 100%;
#   }
#
#   /* Renders the cells w/ positive confidence interval to green. */
#   .ci-display-good-change {
#     background-color: rgb(221,255,187);
#     color: green;
#   }
#
#   /* Renders the cells w/ negative confidence interval to red. */
#   .ci-display-bad-change {
#     background-color: rgb(255,221,187);
#     color: red;
#   }
#
#   .ci-display-ratio {
#     font-size: 120%; /* Renders the ratio value in larger font. */
#   }
#
#   .ci-display-ci-range {
#     white-space: nowrap;  /* Don't break line in the middle of CI range.
#   }
#
#   /* Display the footnote message for 5s then fade out. Adjusted from */
#   /* https://stackoverflow.com/a/43397509/2771265. */
#   #feature-request-footnote {
#     overflow:hidden;
#     position:relative;
#   }
#
#   #feature-request-auto-hide {
#     -webkit-animation: css-animation 10s forwards;
#     animation: css-animation 10s forwards;
#   }
#
#   @keyframes css-animation {
#     0%   {opacity: 1;}
#     100% {opacity: 0;}
#   }
#
#   @-webkit-keyframes css-animation {
#     0%   {opacity: 1;}
#     100% {opacity: 0;}
#   }
# </style>

# %% [markdown]
# Column name as 'table.column' may or may not work, but it won't give you a wrong result without notice. The SQL just won't compile.

# %%
# table.column style still works for MH.
spend_with_tbl = 'imp.cpc_cost_usd'
conversions_with_tbl = 'imp.conversions_valid_for_revenue'
clicks_with_tbl = 'imp.clicks_valid_for_revenue'
cvr_with_tbl = Ratio(conversions_with_tbl, clicks_with_tbl, 'cvr')
cpc_with_tbl = Ratio(spend_with_tbl, clicks_with_tbl, 'cpc')
cpd_with_tbl = Ratio(conversions_with_tbl, spend_with_tbl, 'cpd')
ms_with_tbl = MetricList((cvr_with_tbl, cpc_with_tbl, cpd_with_tbl),
                         where=filters)
mh_with_tbl = MH('expt_id', 2004375, 'ads_customer_id', ms_with_tbl)
mh_with_tbl.compute_on_sql(table)
# Out:
# Warning: Metric sum(imp.conversions_valid_for_revenue) uses column imp.conversions_valid_for_revenue which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.clicks_valid_for_revenue) uses column imp.clicks_valid_for_revenue which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.cpc_cost_usd) uses column imp.cpc_cost_usd which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.clicks_valid_for_revenue) uses column imp.clicks_valid_for_revenue which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.conversions_valid_for_revenue) uses column imp.conversions_valid_for_revenue which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.cpc_cost_usd) uses column imp.cpc_cost_usd which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
#          cvr_mh_ratio  cpc_mh_ratio  cpd_mh_ratio
# expt_id
# 2004376      0.421622      -0.03072      0.590635

# %%
# But fails on Jackknife.
jk_with_tbl = Jackknife('rasta_cookie_bucket', mh_with_tbl, 0.95)
jk_with_tbl.compute_on_sql(table)
# Out:
# Warning: Metric sum(imp.conversions_valid_for_revenue) uses column imp.conversions_valid_for_revenue which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.clicks_valid_for_revenue) uses column imp.clicks_valid_for_revenue which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.cpc_cost_usd) uses column imp.cpc_cost_usd which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.clicks_valid_for_revenue) uses column imp.clicks_valid_for_revenue which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.conversions_valid_for_revenue) uses column imp.conversions_valid_for_revenue which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# Warning: Metric sum(imp.cpc_cost_usd) uses column imp.cpc_cost_usd which has a ".". A "." in the column name is not fully supported. If the generated query fails, try to get rid of the ".".
# DremelExecutionError: Error executing Dremel query
#
# ---------------------------------------------------------------------------
#
#       1 WITH
#       2 FilteredData AS (SELECT
#       3   *
#       4 FROM shopping_analysis.ps_session.all AS t,
#       5 UNNEST(t.ps_event) AS ev,
#       6 UNNEST(ev.experimentid) AS expt_id,
#       7 UNNEST(ev.impression_set) AS imp
#       8 WHERE
#       9
#      10   _PARTITION_DATE = '20200906'
#      11   AND ev.page_type != 'AFS'
#      12   AND ev.good_for_revenue
#      13   AND imp.slot > 0
#      14   AND imp.impression_type = 'PLA'
#      15   AND imp.clicks_valid_for_revenue > 0
#      16   AND conversion_within_threshold
#      17   AND expt_id IN (2004375, 2004376)),
#      18 AllSlices AS (SELECT
#      19   ARRAY_AGG(DISTINCT expt_id) AS expt_id,
#      20   ARRAY_AGG(DISTINCT ads_customer_id) AS ads_customer_id,
#      21   ARRAY_AGG(DISTINCT rasta_cookie_bucket) AS rasta_cookie_bucket
#      22 FROM FilteredData),
#      23 LOO AS (SELECT DISTINCT
#      24   expt_id,
#      25   ads_customer_id,
#      26   rasta_cookie_bucket AS _resample_idx,
#               ▼
# ---> 27   SUM(imp.conversions_valid_for_revenue) OVER (PARTITION BY expt_id, ads_customer_id) - COALESCE(SUM(imp.conversions_valid_for_revenue) OVER (PARTITION BY expt_id, ads_customer_id, rasta_cookie_bucket), 0) AS sum_imp_point_conversions_valid_for_revenue,
#               ▲
#      28   SUM(imp.clicks_valid_for_revenue) OVER (PARTITION BY expt_id, ads_customer_id) - COALESCE(SUM(imp.clicks_valid_for_revenue) OVER (PARTITION BY expt_id, ads_customer_id, rasta_cookie_bucket), 0) AS sum_imp_point_clicks_valid_for_revenue,
#      29   SUM(imp.cpc_cost_usd) OVER (PARTITION BY expt_id, ads_customer_id) - COALESCE(SUM(imp.cpc_cost_usd) OVER (PARTITION BY expt_id, ads_customer_id, rasta_cookie_bucket), 0) AS sum_imp_point_cpc_cost_usd,
#      30   SUM(imp.clicks_valid_for_revenue) OVER (PARTITION BY expt_id, ads_customer_id) - COALESCE(SUM(imp.clicks_valid_for_revenue) OVER (PARTITION BY expt_id, ads_customer_id, rasta_cookie_bucket), 0) AS sum_imp_point_clicks_valid_for_revenue_1,
#      31   SUM(imp.conversions_valid_for_revenue) OVER (PARTITION BY expt_id, ads_customer_id) - COALESCE(SUM(imp.conversions_valid_for_revenue) OVER (PARTITION BY expt_id, ads_customer_id, rasta_cookie_bucket), 0) AS sum_imp_point_conversions_valid_for_revenue_1,
#      32   SUM(imp.cpc_cost_usd) OVER (PARTITION BY expt_id, ads_customer_id) - COALESCE(SUM(imp.cpc_cost_usd) OVER (PARTITION BY expt_id, ads_customer_id, rasta_cookie_bucket), 0) AS sum_imp_point_cpc_cost_usd_1
#      33 FROM AllSlices
#      34 JOIN
#      35 UNNEST (expt_id) AS expt_id
#      36 JOIN
#      37 UNNEST (ads_customer_id) AS ads_customer_id
#      38 JOIN
#      39 UNNEST (rasta_cookie_bucket) AS rasta_cookie_bucket
#      40 LEFT JOIN
#      41 FilteredData
#      42 USING (expt_id, ads_customer_id, rasta_cookie_bucket)),
#      43 RawValueForExpt_idComparison AS (SELECT
#      44   _resample_idx,
#      45   expt_id,
#      46   ads_customer_id,
#      47   SUM(sum_imp_point_conversions_valid_for_revenue) AS sum_imp_point_conversions_valid_for_revenue,
#      48   SUM(sum_imp_point_clicks_valid_for_revenue) AS sum_imp_point_clicks_valid_for_revenue,
#      49   SUM(sum_imp_point_cpc_cost_usd) AS sum_imp_point_cpc_cost_usd,
#      50   SUM(sum_imp_point_clicks_valid_for_revenue_1) AS sum_imp_point_clicks_valid_for_revenue_1,
#      51   SUM(sum_imp_point_conversions_valid_for_revenue_1) AS sum_imp_point_conversions_valid_for_revenue_1,
#      52   SUM(sum_imp_point_cpc_cost_usd_1) AS sum_imp_point_cpc_cost_usd_1
#      53 FROM LOO
#      54 GROUP BY _resample_idx, expt_id, ads_customer_id),
#      55 BaseValueWhereExpt_idEquals2004375 AS (SELECT
#      56   * EXCEPT (expt_id)
#      57 FROM RawValueForExpt_idComparison
#      58 WHERE
#      59 expt_id = 2004375),
#      60 ResampledResults AS (SELECT
#      61   expt_id,
#      62   _resample_idx,
#      63   100 * SAFE_DIVIDE(
#      64     SUM(SAFE_DIVIDE(
#      65       RawValueForExpt_idComparison.sum_imp_point_conversions_valid_for_revenue * BaseValueWhereExpt_idEquals2004375.sum_imp_point_clicks_valid_for_revenue,
#      66       BaseValueWhereExpt_idEquals2004375.sum_imp_point_clicks_valid_for_revenue + RawValueForExpt_idComparison.sum_imp_point_clicks_valid_for_revenue)),
#      67     SUM(SAFE_DIVIDE(
#      68       BaseValueWhereExpt_idEquals2004375.sum_imp_point_conversions_valid_for_revenue * RawValueForExpt_idComparison.sum_imp_point_clicks_valid_for_revenue,
#      69       BaseValueWhereExpt_idEquals2004375.sum_imp_point_clicks_valid_for_revenue + RawValueForExpt_idComparison.sum_imp_point_clicks_valid_for_revenue))) - 100 AS cvr_mh_ratio,
#      70   100 * SAFE_DIVIDE(
#      71     SUM(SAFE_DIVIDE(
#      72       RawValueForExpt_idComparison.sum_imp_point_cpc_cost_usd * BaseValueWhereExpt_idEquals2004375.sum_imp_point_clicks_valid_for_revenue,
#      73       BaseValueWhereExpt_idEquals2004375.sum_imp_point_clicks_valid_for_revenue + RawValueForExpt_idComparison.sum_imp_point_clicks_valid_for_revenue)),
#      74     SUM(SAFE_DIVIDE(
#      75       BaseValueWhereExpt_idEquals2004375.sum_imp_point_cpc_cost_usd * RawValueForExpt_idComparison.sum_imp_point_clicks_valid_for_revenue,
#      76       BaseValueWhereExpt_idEquals2004375.sum_imp_point_clicks_valid_for_revenue + RawValueForExpt_idComparison.sum_imp_point_clicks_valid_for_revenue))) - 100 AS cpc_mh_ratio,
#      77   100 * SAFE_DIVIDE(
#      78     SUM(SAFE_DIVIDE(
#      79       RawValueForExpt_idComparison.sum_imp_point_conversions_valid_for_revenue * BaseValueWhereExpt_idEquals2004375.sum_imp_point_cpc_cost_usd,
#      80       BaseValueWhereExpt_idEquals2004375.sum_imp_point_cpc_cost_usd + RawValueForExpt_idComparison.sum_imp_point_cpc_cost_usd)),
#      81     SUM(SAFE_DIVIDE(
#      82       BaseValueWhereExpt_idEquals2004375.sum_imp_point_conversions_valid_for_revenue * RawValueForExpt_idComparison.sum_imp_point_cpc_cost_usd,
#      83       BaseValueWhereExpt_idEquals2004375.sum_imp_point_cpc_cost_usd + RawValueForExpt_idComparison.sum_imp_point_cpc_cost_usd))) - 100 AS cpd_mh_ratio
#      84 FROM RawValueForExpt_idComparison
#      85 JOIN
#      86 BaseValueWhereExpt_idEquals2004375
#      87 USING (_resample_idx, ads_customer_id)
#      88 WHERE
#      89 expt_id != 2004375
#      90 GROUP BY expt_id, _resample_idx),
#      91 RawValueForExpt_idComparison_1 AS (SELECT
#      92   expt_id,
#      93   ads_customer_id,
#      94   SUM(imp.conversions_valid_for_revenue) AS sum_imp_point_conversions_valid_for_revenue,
#      95   SUM(imp.clicks_valid_for_revenue) AS sum_imp_point_clicks_valid_for_revenue,
#      96   SUM(imp.cpc_cost_usd) AS sum_imp_point_cpc_cost_usd,
#      97   SUM(imp.clicks_valid_for_revenue) AS sum_imp_point_clicks_valid_for_revenue_1,
#      98   SUM(imp.conversions_valid_for_revenue) AS sum_imp_point_conversions_valid_for_revenue_1,
#      99   SUM(imp.cpc_cost_usd) AS sum_imp_point_cpc_cost_usd_1
#     100 FROM shopping_analysis.ps_session.all AS t,
#     101 UNNEST(t.ps_event) AS ev,
#     102 UNNEST(ev.experimentid) AS expt_id,
#     103 UNNEST(ev.impression_set) AS imp
#     104 WHERE
#     105
#     106   _PARTITION_DATE = '20200906'
#     107   AND ev.page_type != 'AFS'
#     108   AND ev.good_for_revenue
#     109   AND imp.slot > 0
#     110   AND imp.impression_type = 'PLA'
#     111   AND imp.clicks_valid_for_revenue > 0
#     112   AND conversion_within_threshold
#     113   AND expt_id IN (2004375, 2004376)
#     114 GROUP BY expt_id, ads_customer_id),
#     115 BaseValueWhereExpt_idEquals2004376 AS (SELECT
#     116   * EXCEPT (expt_id)
#     117 FROM RawValueForExpt_idComparison_1
#     118 WHERE
#     119 expt_id = 2004375),
#     120 JackknifeSE AS (SELECT
#     121   expt_id,
#     122   STDDEV_SAMP(cvr_mh_ratio) * (SAFE_DIVIDE((COUNT(cvr_mh_ratio) - 1), SQRT(COUNT(cvr_mh_ratio)))) AS cvr_mh_ratio_jackknife_se,
#     123   COUNT(cvr_mh_ratio) - 1 AS cvr_mh_ratio_dof,
#     124   STDDEV_SAMP(cpc_mh_ratio) * (SAFE_DIVIDE((COUNT(cpc_mh_ratio) - 1), SQRT(COUNT(cpc_mh_ratio)))) AS cpc_mh_ratio_jackknife_se,
#     125   COUNT(cpc_mh_ratio) - 1 AS cpc_mh_ratio_dof,
#     126   STDDEV_SAMP(cpd_mh_ratio) * (SAFE_DIVIDE((COUNT(cpd_mh_ratio) - 1), SQRT(COUNT(cpd_mh_ratio)))) AS cpd_mh_ratio_jackknife_se,
#     127   COUNT(cpd_mh_ratio) - 1 AS cpd_mh_ratio_dof
#     128 FROM ResampledResults
#     129 GROUP BY expt_id),
#     130 JackknifePointEstimate AS (SELECT
#     131   expt_id,
#     132   100 * SAFE_DIVIDE(
#     133     SUM(SAFE_DIVIDE(
#     134       RawValueForExpt_idComparison_1.sum_imp_point_conversions_valid_for_revenue * BaseValueWhereExpt_idEquals2004376.sum_imp_point_clicks_valid_for_revenue,
#     135       BaseValueWhereExpt_idEquals2004376.sum_imp_point_clicks_valid_for_revenue + RawValueForExpt_idComparison_1.sum_imp_point_clicks_valid_for_revenue)),
#     136     SUM(SAFE_DIVIDE(
#     137       BaseValueWhereExpt_idEquals2004376.sum_imp_point_conversions_valid_for_revenue * RawValueForExpt_idComparison_1.sum_imp_point_clicks_valid_for_revenue,
#     138       BaseValueWhereExpt_idEquals2004376.sum_imp_point_clicks_valid_for_revenue + RawValueForExpt_idComparison_1.sum_imp_point_clicks_valid_for_revenue))) - 100 AS cvr_mh_ratio,
#     139   100 * SAFE_DIVIDE(
#     140     SUM(SAFE_DIVIDE(
#     141       RawValueForExpt_idComparison_1.sum_imp_point_cpc_cost_usd * BaseValueWhereExpt_idEquals2004376.sum_imp_point_clicks_valid_for_revenue,
#     142       BaseValueWhereExpt_idEquals2004376.sum_imp_point_clicks_valid_for_revenue + RawValueForExpt_idComparison_1.sum_imp_point_clicks_valid_for_revenue)),
#     143     SUM(SAFE_DIVIDE(
#     144       BaseValueWhereExpt_idEquals2004376.sum_imp_point_cpc_cost_usd * RawValueForExpt_idComparison_1.sum_imp_point_clicks_valid_for_revenue,
#     145       BaseValueWhereExpt_idEquals2004376.sum_imp_point_clicks_valid_for_revenue + RawValueForExpt_idComparison_1.sum_imp_point_clicks_valid_for_revenue))) - 100 AS cpc_mh_ratio,
#     146   100 * SAFE_DIVIDE(
#     147     SUM(SAFE_DIVIDE(
#     148       RawValueForExpt_idComparison_1.sum_imp_point_conversions_valid_for_revenue * BaseValueWhereExpt_idEquals2004376.sum_imp_point_cpc_cost_usd,
#     149       BaseValueWhereExpt_idEquals2004376.sum_imp_point_cpc_cost_usd + RawValueForExpt_idComparison_1.sum_imp_point_cpc_cost_usd)),
#     150     SUM(SAFE_DIVIDE(
#     151       BaseValueWhereExpt_idEquals2004376.sum_imp_point_conversions_valid_for_revenue * RawValueForExpt_idComparison_1.sum_imp_point_cpc_cost_usd,
#     152       BaseValueWhereExpt_idEquals2004376.sum_imp_point_cpc_cost_usd + RawValueForExpt_idComparison_1.sum_imp_point_cpc_cost_usd))) - 100 AS cpd_mh_ratio
#     153 FROM RawValueForExpt_idComparison_1
#     154 JOIN
#     155 BaseValueWhereExpt_idEquals2004376
#     156 USING (ads_customer_id)
#     157 WHERE
#     158 expt_id != 2004375
#     159 GROUP BY expt_id)
#     160 SELECT
#     161   expt_id,
#     162   JackknifePointEstimate.cvr_mh_ratio AS cvr_mh_ratio,
#     163   JackknifeSE.cvr_mh_ratio_jackknife_se AS cvr_mh_ratio_jackknife_se,
#     164   JackknifeSE.cvr_mh_ratio_dof AS cvr_mh_ratio_dof,
#     165   JackknifePointEstimate.cpc_mh_ratio AS cpc_mh_ratio,
#     166   JackknifeSE.cpc_mh_ratio_jackknife_se AS cpc_mh_ratio_jackknife_se,
#     167   JackknifeSE.cpc_mh_ratio_dof AS cpc_mh_ratio_dof,
#     168   JackknifePointEstimate.cpd_mh_ratio AS cpd_mh_ratio,
#     169   JackknifeSE.cpd_mh_ratio_jackknife_se AS cpd_mh_ratio_jackknife_se,
#     170   JackknifeSE.cpd_mh_ratio_dof AS cpd_mh_ratio_dof
#     171 FROM JackknifePointEstimate
#     172 LEFT JOIN
#     173 JackknifeSE
#     174 USING (expt_id)
#
# Unrecognized name: imp
#
# Current SQL dialect is 'GoogleSQL'; use dremel.SetLanguage('DremelSQL') to change it.
#
# Use %%dremel for non-query Dremel commands.

# %% [markdown]
# ## Difference-in-Differences

# %%
# Query compiles but exhausts memory.
pre = PercentChange('expt_id', 2004375, ms, where='date = "2020-09-04"')
post = PercentChange('expt_id', 2004375, ms, where='date = "2020-09-05"')
did = post - pre
jk = Jackknife('rasta_cookie_bucket', did, 0.95)
res = jk.compute_on_sql(table)
res
# Out:
# DremelExecutionError: Error executing Dremel query
#
# ---------------------------------------------------------------------------
#
#       1 WITH
#       2 FilteredData AS (SELECT
#       3   *
#       4 FROM shopping_analysis.ps_session.all AS t,
#       5 UNNEST(t.ps_event) AS ev,
#       6 UNNEST(ev.experimentid) AS expt_id,
#       7 UNNEST(ev.impression_set) AS imp
#       8 WHERE
#       9
#      10   _PARTITION_DATE BETWEEN '20200904' AND '20200905'
#      11   AND ev.page_type != 'AFS'
#      12   AND ev.good_for_revenue
#      13   AND imp.slot > 0
#      14   AND imp.impression_type = 'PLA'
#      15   AND imp.clicks_valid_for_revenue > 0
#      16   AND conversion_within_threshold
#      17   AND expt_id IN (2004375, 2004376)),
#      18 AllSlices AS (SELECT
#      19   ARRAY_AGG(DISTINCT expt_id) AS expt_id,
#      20   ARRAY_AGG(DISTINCT rasta_cookie_bucket) AS rasta_cookie_bucket
#      21 FROM FilteredData),
#      22 LOO AS (SELECT DISTINCT
#      23   expt_id,
#      24   rasta_cookie_bucket AS _resample_idx,
#      25   (SUM(IF(date = "2020-09-05", cpc_cost_usd, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-05", cpc_cost_usd, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_cpc_cost_usd,
#      26   (SUM(IF(date = "2020-09-05", clicks_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-05", clicks_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_clicks_valid_for_revenue,
#      27   (SUM(IF(date = "2020-09-05", conversions_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-05", conversions_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_conversions_valid_for_revenue,
#      28   (SUM(IF(date = "2020-09-05", clicks_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-05", clicks_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_clicks_valid_for_revenue_1,
#      29   (SUM(IF(date = "2020-09-05", conversions_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-05", conversions_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_conversions_valid_for_revenue_1,
#      30   (SUM(IF(date = "2020-09-05", cpc_cost_usd, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-05", cpc_cost_usd, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_cpc_cost_usd_1,
#      31   (SUM(IF(date = "2020-09-04", cpc_cost_usd, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-04", cpc_cost_usd, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_cpc_cost_usd_2,
#      32   (SUM(IF(date = "2020-09-04", clicks_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-04", clicks_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_clicks_valid_for_revenue_2,
#      33   (SUM(IF(date = "2020-09-04", conversions_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-04", conversions_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_conversions_valid_for_revenue_2,
#      34   (SUM(IF(date = "2020-09-04", clicks_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-04", clicks_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_clicks_valid_for_revenue_3,
#      35   (SUM(IF(date = "2020-09-04", conversions_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-04", conversions_valid_for_revenue, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_conversions_valid_for_revenue_3,
#      36   (SUM(IF(date = "2020-09-04", cpc_cost_usd, NULL)) OVER (PARTITION BY expt_id)) - (COALESCE(SUM(IF(date = "2020-09-04", cpc_cost_usd, NULL)) OVER (PARTITION BY expt_id, rasta_cookie_bucket), 0)) AS sum_cpc_cost_usd_3
#      37 FROM AllSlices
#      38 JOIN
#      39 UNNEST (expt_id) AS expt_id
#      40 JOIN
#      41 UNNEST (rasta_cookie_bucket) AS rasta_cookie_bucket
#      42 LEFT JOIN
#      43 FilteredData
#      44 USING (expt_id, rasta_cookie_bucket)),
#      45 RawValueForExpt_idComparison AS (SELECT
#      46   _resample_idx,
#      47   expt_id,
#      48   SAFE_DIVIDE(SUM(sum_cpc_cost_usd), SUM(sum_clicks_valid_for_revenue)) AS cpc,
#      49   SAFE_DIVIDE(SUM(sum_conversions_valid_for_revenue), SUM(sum_clicks_valid_for_revenue_1)) AS cvr,
#      50   SAFE_DIVIDE(SUM(sum_conversions_valid_for_revenue_1), SUM(sum_cpc_cost_usd_1)) AS cpd
#      51 FROM LOO
#      52 GROUP BY _resample_idx, expt_id),
#      53 BaseValueWhereExpt_idEquals2004375 AS (SELECT
#      54   * EXCEPT (expt_id)
#      55 FROM RawValueForExpt_idComparison
#      56 WHERE
#      57 expt_id = 2004375),
#      58 RawValueForExpt_idComparison_1 AS (SELECT
#      59   _resample_idx,
#      60   expt_id,
#      61   SAFE_DIVIDE(SUM(sum_cpc_cost_usd_2), SUM(sum_clicks_valid_for_revenue_2)) AS cpc,
#      62   SAFE_DIVIDE(SUM(sum_conversions_valid_for_revenue_2), SUM(sum_clicks_valid_for_revenue_3)) AS cvr,
#      63   SAFE_DIVIDE(SUM(sum_conversions_valid_for_revenue_3), SUM(sum_cpc_cost_usd_3)) AS cpd
#      64 FROM LOO
#      65 GROUP BY _resample_idx, expt_id),
#      66 BaseValueWhereExpt_idEquals2004376 AS (SELECT
#      67   * EXCEPT (expt_id)
#      68 FROM RawValueForExpt_idComparison_1
#      69 WHERE
#      70 expt_id = 2004375),
#      71 MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable0 AS (SELECT
#      72   expt_id,
#      73   _resample_idx,
#      74   SAFE_DIVIDE(RawValueForExpt_idComparison.cpc, (BaseValueWhereExpt_idEquals2004375.cpc)) * 100 - 100 AS cpc_percent_change,
#      75   SAFE_DIVIDE(RawValueForExpt_idComparison.cvr, (BaseValueWhereExpt_idEquals2004375.cvr)) * 100 - 100 AS cvr_percent_change,
#      76   SAFE_DIVIDE(RawValueForExpt_idComparison.cpd, (BaseValueWhereExpt_idEquals2004375.cpd)) * 100 - 100 AS cpd_percent_change
#      77 FROM RawValueForExpt_idComparison
#      78 JOIN
#      79 BaseValueWhereExpt_idEquals2004375
#      80 USING (_resample_idx)
#      81 WHERE
#      82 expt_id != 2004375),
#      83 MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable1 AS (SELECT
#      84   expt_id,
#      85   _resample_idx,
#      86   SAFE_DIVIDE(RawValueForExpt_idComparison_1.cpc, (BaseValueWhereExpt_idEquals2004376.cpc)) * 100 - 100 AS cpc_percent_change,
#      87   SAFE_DIVIDE(RawValueForExpt_idComparison_1.cvr, (BaseValueWhereExpt_idEquals2004376.cvr)) * 100 - 100 AS cvr_percent_change,
#      88   SAFE_DIVIDE(RawValueForExpt_idComparison_1.cpd, (BaseValueWhereExpt_idEquals2004376.cpd)) * 100 - 100 AS cpd_percent_change
#      89 FROM RawValueForExpt_idComparison_1
#      90 JOIN
#      91 BaseValueWhereExpt_idEquals2004376
#      92 USING (_resample_idx)
#      93 WHERE
#      94 expt_id != 2004375),
#      95 ResampledResults AS (SELECT
#      96   expt_id,
#      97   _resample_idx,
#      98   MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable0.cpc_percent_change - MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable1.cpc_percent_change AS cpc_percent_change_minus_cpc_percent_change,
#      99   MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable0.cvr_percent_change - MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable1.cvr_percent_change AS cvr_percent_change_minus_cvr_percent_change,
#     100   MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable0.cpd_percent_change - MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable1.cpd_percent_change AS cpd_percent_change_minus_cpd_percent_change
#     101 FROM MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable0
#     102 FULL JOIN
#     103 MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable1
#     104 USING (expt_id, _resample_idx)),
#     105 RawValueForExpt_idComparison_2 AS (SELECT
#     106   expt_id,
#     107   SAFE_DIVIDE(SUM(IF(date = "2020-09-05", cpc_cost_usd, NULL)), SUM(IF(date = "2020-09-05", clicks_valid_for_revenue, NULL))) AS cpc,
#     108   SAFE_DIVIDE(SUM(IF(date = "2020-09-05", conversions_valid_for_revenue, NULL)), SUM(IF(date = "2020-09-05", clicks_valid_for_revenue, NULL))) AS cvr,
#     109   SAFE_DIVIDE(SUM(IF(date = "2020-09-05", conversions_valid_for_revenue, NULL)), SUM(IF(date = "2020-09-05", cpc_cost_usd, NULL))) AS cpd
#     110 FROM shopping_analysis.ps_session.all AS t,
#     111 UNNEST(t.ps_event) AS ev,
#     112 UNNEST(ev.experimentid) AS expt_id,
#     113 UNNEST(ev.impression_set) AS imp
#     114 WHERE
#     115
#     116   _PARTITION_DATE BETWEEN '20200904' AND '20200905'
#     117   AND ev.page_type != 'AFS'
#     118   AND ev.good_for_revenue
#     119   AND imp.slot > 0
#     120   AND imp.impression_type = 'PLA'
#     121   AND imp.clicks_valid_for_revenue > 0
#     122   AND conversion_within_threshold
#     123   AND expt_id IN (2004375, 2004376)
#     124 GROUP BY expt_id),
#     125 BaseValueWhereExpt_idEquals2004377 AS (SELECT
#     126   * EXCEPT (expt_id)
#     127 FROM RawValueForExpt_idComparison_2
#     128 WHERE
#     129 expt_id = 2004375),
#     130 RawValueForExpt_idComparison_3 AS (SELECT
#     131   expt_id,
#     132   SAFE_DIVIDE(SUM(IF(date = "2020-09-04", cpc_cost_usd, NULL)), SUM(IF(date = "2020-09-04", clicks_valid_for_revenue, NULL))) AS cpc,
#     133   SAFE_DIVIDE(SUM(IF(date = "2020-09-04", conversions_valid_for_revenue, NULL)), SUM(IF(date = "2020-09-04", clicks_valid_for_revenue, NULL))) AS cvr,
#     134   SAFE_DIVIDE(SUM(IF(date = "2020-09-04", conversions_valid_for_revenue, NULL)), SUM(IF(date = "2020-09-04", cpc_cost_usd, NULL))) AS cpd
#     135 FROM shopping_analysis.ps_session.all AS t,
#     136 UNNEST(t.ps_event) AS ev,
#     137 UNNEST(ev.experimentid) AS expt_id,
#     138 UNNEST(ev.impression_set) AS imp
#     139 WHERE
#     140
#     141   _PARTITION_DATE BETWEEN '20200904' AND '20200905'
#     142   AND ev.page_type != 'AFS'
#     143   AND ev.good_for_revenue
#     144   AND imp.slot > 0
#     145   AND imp.impression_type = 'PLA'
#     146   AND imp.clicks_valid_for_revenue > 0
#     147   AND conversion_within_threshold
#     148   AND expt_id IN (2004375, 2004376)
#     149 GROUP BY expt_id),
#     150 BaseValueWhereExpt_idEquals2004378 AS (SELECT
#     151   * EXCEPT (expt_id)
#     152 FROM RawValueForExpt_idComparison_3
#     153 WHERE
#     154 expt_id = 2004375),
#     155 MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable2 AS (SELECT
#     156   expt_id,
#     157   SAFE_DIVIDE(RawValueForExpt_idComparison_2.cpc, (BaseValueWhereExpt_idEquals2004377.cpc)) * 100 - 100 AS cpc_percent_change,
#     158   SAFE_DIVIDE(RawValueForExpt_idComparison_2.cvr, (BaseValueWhereExpt_idEquals2004377.cvr)) * 100 - 100 AS cvr_percent_change,
#     159   SAFE_DIVIDE(RawValueForExpt_idComparison_2.cpd, (BaseValueWhereExpt_idEquals2004377.cpd)) * 100 - 100 AS cpd_percent_change
#     160 FROM RawValueForExpt_idComparison_2
#     161 CROSS JOIN
#     162 BaseValueWhereExpt_idEquals2004377
#     163 WHERE
#     164 expt_id != 2004375),
#     165 MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable3 AS (SELECT
#     166   expt_id,
#     167   SAFE_DIVIDE(RawValueForExpt_idComparison_3.cpc, (BaseValueWhereExpt_idEquals2004378.cpc)) * 100 - 100 AS cpc_percent_change,
#     168   SAFE_DIVIDE(RawValueForExpt_idComparison_3.cvr, (BaseValueWhereExpt_idEquals2004378.cvr)) * 100 - 100 AS cvr_percent_change,
#     169   SAFE_DIVIDE(RawValueForExpt_idComparison_3.cpd, (BaseValueWhereExpt_idEquals2004378.cpd)) * 100 - 100 AS cpd_percent_change
#     170 FROM RawValueForExpt_idComparison_3
#     171 CROSS JOIN
#     172 BaseValueWhereExpt_idEquals2004378
#     173 WHERE
#     174 expt_id != 2004375),
#     175 JackknifeSE AS (SELECT
#     176   expt_id,
#     177   STDDEV_SAMP(cpc_percent_change_minus_cpc_percent_change) * (SAFE_DIVIDE((COUNT(cpc_percent_change_minus_cpc_percent_change) - 1), SQRT(COUNT(cpc_percent_change_minus_cpc_percent_change)))) AS cpc_percent_change_minus_cpc_percent_change_jackknife_se,
#     178   COUNT(cpc_percent_change_minus_cpc_percent_change) - 1 AS cpc_percent_change_minus_cpc_percent_change_dof,
#     179   STDDEV_SAMP(cvr_percent_change_minus_cvr_percent_change) * (SAFE_DIVIDE((COUNT(cvr_percent_change_minus_cvr_percent_change) - 1), SQRT(COUNT(cvr_percent_change_minus_cvr_percent_change)))) AS cvr_percent_change_minus_cvr_percent_change_jackknife_se,
#     180   COUNT(cvr_percent_change_minus_cvr_percent_change) - 1 AS cvr_percent_change_minus_cvr_percent_change_dof,
#     181   STDDEV_SAMP(cpd_percent_change_minus_cpd_percent_change) * (SAFE_DIVIDE((COUNT(cpd_percent_change_minus_cpd_percent_change) - 1), SQRT(COUNT(cpd_percent_change_minus_cpd_percent_change)))) AS cpd_percent_change_minus_cpd_percent_change_jackknife_se,
#     182   COUNT(cpd_percent_change_minus_cpd_percent_change) - 1 AS cpd_percent_change_minus_cpd_percent_change_dof
#     183 FROM ResampledResults
#     184 GROUP BY expt_id),
#     185 JackknifePointEstimate AS (SELECT
#     186   expt_id,
#     187   MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable2.cpc_percent_change - MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable3.cpc_percent_change AS cpc_percent_change_minus_cpc_percent_change,
#     188   MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable2.cvr_percent_change - MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable3.cvr_percent_change AS cvr_percent_change_minus_cvr_percent_change,
#     189   MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable2.cpd_percent_change - MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable3.cpd_percent_change AS cpd_percent_change_minus_cpd_percent_change
#     190 FROM MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable2
#     191 FULL JOIN
#     192 MetricList_cpc_comma_cvr_comma_cpd_Percent_Change_minus_MetricList_cpc_comma_cvr_comma_cpd_Percent_ChangeTable3
#     193 USING (expt_id))
#     194 SELECT
#     195   expt_id,
#     196   JackknifePointEstimate.cpc_percent_change_minus_cpc_percent_change AS cpc_percent_change_minus_cpc_percent_change,
#     197   JackknifeSE.cpc_percent_change_minus_cpc_percent_change_jackknife_se AS cpc_percent_change_minus_cpc_percent_change_jackknife_se,
#     198   JackknifeSE.cpc_percent_change_minus_cpc_percent_change_dof AS cpc_percent_change_minus_cpc_percent_change_dof,
#     199   JackknifePointEstimate.cvr_percent_change_minus_cvr_percent_change AS cvr_percent_change_minus_cvr_percent_change,
#     200   JackknifeSE.cvr_percent_change_minus_cvr_percent_change_jackknife_se AS cvr_percent_change_minus_cvr_percent_change_jackknife_se,
#     201   JackknifeSE.cvr_percent_change_minus_cvr_percent_change_dof AS cvr_percent_change_minus_cvr_percent_change_dof,
#     202   JackknifePointEstimate.cpd_percent_change_minus_cpd_percent_change AS cpd_percent_change_minus_cpd_percent_change,
#     203   JackknifeSE.cpd_percent_change_minus_cpd_percent_change_jackknife_se AS cpd_percent_change_minus_cpd_percent_change_jackknife_se,
#     204   JackknifeSE.cpd_percent_change_minus_cpd_percent_change_dof AS cpd_percent_change_minus_cpd_percent_change_dof
#     205 FROM JackknifePointEstimate
#     206 LEFT JOIN
#     207 JackknifeSE
#     208 USING (expt_id)
#
# The query could not be executed in the allotted memory. Peak usage: 127% of limit.
# Top memory consumer(s):
#   sort operations used for analytic OVER() clauses: 99%
#   other/unattributed: 1%
#
# Error details:
# message: "Check http://go/dremel-memory-tracker-update-faq"
# resource_exhausted_error {
#   resource_type: MEMORY
# }
#
#
# Current SQL dialect is 'GoogleSQL'; use dremel.SetLanguage('DremelSQL') to change it.
#
# Use %%dremel for non-query Dremel commands.

# %%
# Preaggregation solves the memory issue.
table = '''
SELECT 
  date,
  expt_id,
  rasta_cookie_bucket,
  SUM(cpc_cost_usd) AS cpc_cost_usd,
  SUM(conversions_valid_for_revenue) AS conversions_valid_for_revenue,
  SUM(clicks_valid_for_revenue) AS clicks_valid_for_revenue,
FROM shopping_analysis.ps_session.all AS t,
  UNNEST(t.ps_event) AS ev,
  UNNEST(ev.experimentid) AS expt_id,
  UNNEST(ev.impression_set) AS imp
WHERE
  _PARTITION_DATE BETWEEN '20200904' AND '20200905'
  AND ev.page_type != 'AFS'
  AND ev.good_for_revenue
  AND imp.slot > 0
  AND imp.impression_type = 'PLA'
  AND imp.clicks_valid_for_revenue > 0
  AND conversion_within_threshold
  AND expt_id IN (2004375, 2004376)
GROUP BY 1, 2, 3
'''

ms = MetricList((cpc, cvr, cpd))
pre = PercentChange('expt_id', 2004375, ms, where='date = "2020-09-04"')
post = PercentChange('expt_id', 2004375, ms, where='date = "2020-09-05"')
did = post - pre
jk = Jackknife('rasta_cookie_bucket', did, 0.95)
res = jk.compute_on_sql(table)
res
# Out:
# Metric  cpc_percent_change_minus_cpc_percent_change  ... cpd_percent_change_minus_cpd_percent_change
#                                               Value  ...                          Jackknife CI-upper
# expt_id                                              ...
# 2004376                                    0.123881  ...                                    2.353186
#
# [1 rows x 9 columns]

# %%
res.display()
# Out:
# <script src="https://ssl.gstatic.com/colaboratory/data_table/a6224c040fa35dcf/data_table.js" type="module"></script><div id="IT_id_771093350"></div><script>
#       (() => {
#         const data = [["<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.12%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-0.45, 0.70] %<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.42%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-1.53, 2.37] %<\/span><\/div><\/div>",
# "<div class=\"ci-display-cell\"><div><span class=\"ci-display-ratio\">0.30%<\/span><div class=\"ci-display-flex-line-break\"><\/div><span class=\"ci-display-ci-range\">[-1.75, 2.35] %<\/span><\/div><\/div>"]];
#         const kernelTag = "IT_id_771093350";
#         const listenerId = "Lstid_771093350";
#         const saveCallback = (indices) => {
#         const max = 5000;
#         colabtools.sendMessageToKernel(kernelTag, {action: 'clear'});
#         // Send data back to ipython in batches of 5k indices at a time.
#         // Otherwise notebook silently fails at ~10K indices.
#         for (let i = 0; i < (indices.length - 1) / max + 1; i++) {
#           const indiceList = indices.slice(i * max, (i + 1) * max);
#           colabtools.sendMessageToKernel(
#               kernelTag, {action: 'append', indices: indiceList});
#         }
#         colab.sendMessageToListeners(listenerId);
#       };
#         gvizInteractiveTable.create({
#           data,
#           saveCallback,
#           elementId: "IT_id_771093350",
#           columns: [["string", "cpc_percent_change_minus_cpc_percent_change"], ["string", "cvr_percent_change_minus_cvr_percent_change"], ["string", "cpd_percent_change_minus_cpd_percent_change"]],
#           columnOptions: null,
#           rowsPerPage: 100,
#           helpUrl: "https://colab.corp.google.com/notebooks/interactive_table.ipynb",
#           disableXssSanitization: false,
#           renderAsPlainText: false,
#           suppressOutputScrolling: true,
#         });
#       })();
#     //# sourceURL=table_IT_id_771093350
#     </script>
# <p id=feature-request-footnote><small id=feature-request-auto-hide>Click <a href="http://b/new?component=459832">here</a> to submit bugs or feature requests for the display function.</small></p>
# <style>
#   /* Use light mode CSS even in dark mode to make things consistent. Taken from
#     http://google3/research/colab/frontend/common/output/theme.css
#   */
#   body {
#     --colab-anchor-color: #00e;
#     --colab-primary-text-color: var(--paper-grey-900);
#     --colab-primary-surface-color: var(--paper-white);
#     --colab-secondary-surface-color: #f7f7f7;
#     --colab-highlighted-surface-color: var(--paper-grey-300);
#     --colab-border-color: #dadada;
#     --colab-bold-border-color: #111;
#     --colab-icon-color: #616161;
#   }
#
#   /* For the whole table body. */
#   tbody {
#     text-align: center;
#   }
#
#   /* Make the table scrollable */
#   .google-visualization-table > div:first-child {
#     max-height: 700px;
#   }
#
#   /* When scrolling, the first row of the table keeps its white background */
#   colab-interactive-table .google-visualization-table-tr-head
#     .google-visualization-table-th {
#     background: white;
#   }
#
#   .google-visualization-table {
#     width: auto !important;  /* To disable table from taking up full width. */
#   }
#
#   .google-visualization-table-table {
#     font-size: 10.5pt;  /* Font size for the whole table. */
#   }
#
#   /* Wrap the long column name. */
#   .google-visualization-table-th {
#     max-width: 120px;
#     white-space: normal !important;
#     word-wrap: break-word;
#   }
#
#   /* Get rid of the white padding around color cells. */
#   .google-visualization-table-td {
#     height: 1px;  /* Let the cell grow with text. */
#     padding: 0.5px !important;
#   }
#
#   .ci-display-cell{
#     height: 100%;
#     padding: 5px;
#     /* Center the content in the cell. */
#     display: flex;
#     align-items: center;
#     justify-content: center;
#   }
#
#   /* Formats Dimension column if there is one. */
#   .ci-display-dimension {
#     color: green;
#     padding: 2px;
#   }
#
#   /* Renders the description text. */
#   .ci-display-description-text {
#     color: black;
#   }
#
#   /* Renders the experiment id in blue. */
#   .ci-display-experiment-id {
#     color: #15c;
#   }
#
#   /* Break line in a flex display. */
#   .ci-display-flex-line-break {
#     width: 100%;
#   }
#
#   /* Renders the cells w/ positive confidence interval to green. */
#   .ci-display-good-change {
#     background-color: rgb(221,255,187);
#     color: green;
#   }
#
#   /* Renders the cells w/ negative confidence interval to red. */
#   .ci-display-bad-change {
#     background-color: rgb(255,221,187);
#     color: red;
#   }
#
#   .ci-display-ratio {
#     font-size: 120%; /* Renders the ratio value in larger font. */
#   }
#
#   .ci-display-ci-range {
#     white-space: nowrap;  /* Don't break line in the middle of CI range.
#   }
#
#   /* Display the footnote message for 5s then fade out. Adjusted from */
#   /* https://stackoverflow.com/a/43397509/2771265. */
#   #feature-request-footnote {
#     overflow:hidden;
#     position:relative;
#   }
#
#   #feature-request-auto-hide {
#     -webkit-animation: css-animation 10s forwards;
#     animation: css-animation 10s forwards;
#   }
#
#   @keyframes css-animation {
#     0%   {opacity: 1;}
#     100% {opacity: 0;}
#   }
#
#   @-webkit-keyframes css-animation {
#     0%   {opacity: 1;}
#     100% {opacity: 0;}
#   }
# </style>
